# %% [markdown]
# # Data profiling
# merangkum dataset menggunakan statistik deskriptif untuk memiliki pemahaman yang kuat tentang data

# %%
# import library 
import pandas as pd
import numpy as np
import io
import pandas_profiling

# import data
retail_raw = pd.read_csv('https://dqlab-dataset.s3-ap-southeast-1.amazonaws.com/retail_raw_reduced_data_quality.csv')

# inspeksi tipe data nya
retail_raw.dtypes
# Out:
# order_id         int64
# order_date      object
# customer_id      int64
# city            object
# province        object
# product_id      object
# brand           object
# quantity       float64
# item_price     float64
# dtype: object

# %% [markdown]
# ## Descriptive Statistics
# statistik deskriptif untuk lebih memahami struktur data

# %% [markdown]
# ### Length
# len, menghitung jumlah baris data dalam suatu series / column kecuali null valuenya
# ```
# len(dataframe['kolom'])
# ```
# len akan hanya menghitung elemen dari kolom yang mempunyai nilai

# %%
# Kolom city
length_city = len(retail_raw['city'])
print('Length kolom city:', length_city)

# Tugas Praktek: Kolom product_id
length_product_id = len(retail_raw['product_id'])
print('Length kolom product_id:', length_product_id)
# Out:
# Length kolom city: 5000
# Length kolom product_id: 5000

# %% [markdown]
# ### Count
# count, menghitung jumlah pengamatan non-NA / non-null dalam suatu series / column
# ```
# dataframe['kolom'].count()
# ```

# %%
# Count kolom city
count_city = retail_raw['city'].count()
print('Count kolom count_city:', count_city)

# Tugas praktek: count kolom product_id
count_product_id = retail_raw['product_id'].count()
print('Count kolom product_id:', count_product_id)
# Out:
# Count kolom count_city: 4984
# Count kolom product_id: 4989

# %% [markdown]
# ### Missing Value
# menghitung jumlah missing-value
#
# Jumlah nilai yang hilang diperoleh dari selisih antara Length dan Count

# %%
# Missing value pada kolom city
number_of_missing_values_city = length_city - count_city
float_of_missing_values_city = float(number_of_missing_values_city/length_city)
pct_of_missing_values_city = '{0:.1f}%'.format(float_of_missing_values_city * 100)
print('Persentase missing value kolom city:', pct_of_missing_values_city)

# Tugas praktek: Missing value pada kolom product_id
number_of_missing_values_product_id = length_product_id - count_product_id
float_of_missing_values_product_id = float(number_of_missing_values_product_id/length_product_id)
pct_of_missing_values_product_id = '{0:.1f}%'.format(float_of_missing_values_product_id * 100)
print('Persentase missing value kolom product_id:', pct_of_missing_values_product_id)
# Out:
# Persentase missing value kolom city: 0.3%
# Persentase missing value kolom product_id: 0.2%

# %% [markdown]
# ### Maximum, Minimum, Mean, Medium, Modus dan Standard Deviasi
#
# *   Maximum, mengetahui element terbesar
# *   Minimum, mengetahui element terkecil
# *   Mean, mengetahui nilai rata-rata dari total jumlah elemennya
# *   Medium, mengetahui nilai tengah dari total jumlah elemennya
# *   Modus, mengetahui element yang sering muncul
# *   Standard Deviasi,  mengetahui pemusatan data dan persebarannya
#
# ```
# # maximum
# dataframe['kolom'].max()
# # minimum
# dataframe['kolom'].min()
# # mean
# dataframe['kolom'].mean()
# # median
# dataframe['kolom'].median()
# # modus
# dataframe['kolom'].mode()
# # standar deviasi
# dataframe['kolom'].std()
# ```

# %%
# Deskriptif statistics kolom quantity
print('Kolom quantity')
print('Minimum value: ', retail_raw['quantity'].min())
print('Maximum value: ', retail_raw['quantity'].max())
print('Mean value: ', retail_raw['quantity'].mean())
print('Mode value: ', retail_raw['quantity'].mode())
print('Median value: ', retail_raw['quantity'].median())
print('Standard Deviation value: ', retail_raw['quantity'].std())

# Tugas praktek: Deskriptif statistics kolom item_price
print('\nKolom item_price')
print('Minimum value: ', retail_raw['item_price'].min())
print('Maximum value: ', retail_raw['item_price'].max())
print('Mean value: ', retail_raw['item_price'].mean())
print('Median value: ', retail_raw['item_price'].median())
print('Standard Deviation value: ', retail_raw['item_price'].std())
# Out:
# Kolom quantity
# Minimum value:  1.0
# Maximum value:  720.0
# Mean value:  11.423987164059366
# Mode value:  0    1.0
# dtype: float64
# Median value:  5.0
# Standard Deviation value:  29.442025010811317
#
# Kolom item_price
# Minimum value:  26000.0
# Maximum value:  29762000.0
# Mean value:  933742.7311008623
# Median value:  604000.0
# Standard Deviation value:  1030829.8104242863

# %% [markdown]
# ### Quantile Statistics
# titik potong yang membagi distribusi dalam ukuran yang sama
# - quartile, kuantil yang merupakan pembagian perempatan
# - percentile, dibagi kedalam 10 sepuluh group yang sama
# ```
# # kuartil
# dataframe['kolom'].quantile([.25,.5,.75])
# # persentil
# dataframe['kolom'].percentile([])
# ```

# %%
# Quantile statistics kolom quantity
print('Kolom quantity:')
print(retail_raw['quantity'].quantile([0.25, 0.5, 0.75]))

# Tugas praktek: Quantile statistics kolom item_price
print('\nKolom item_price:')
print(retail_raw['item_price'].quantile([0.25, 0.5, 0.75]))
# Out:
# Kolom quantity:
# 0.25     2.0
# 0.50     5.0
# 0.75    12.0
# Name: quantity, dtype: float64
#
# Kolom item_price:
# 0.25     450000.0
# 0.50     604000.0
# 0.75    1045000.0
# Name: item_price, dtype: float64

# %% [markdown]
# ### Correlation
# Korelasi untuk menemukan hubungan antara variabel numerik yang berkisar antara -1 hingga 1.
# - Korelasi 1 adalah korelasi positif total
# - korelasi -1 adalah korelasi negatif total
# - korelasi 0 adalah korelasi non-linear
# ```
# dataframe[['kolom 1', 'kolom 2']].corr()
# ```

# %%
print('Korelasi quantity dengan item_price')
print(retail_raw[['quantity', 'item_price']].corr())
# Out:
# Korelasi quantity dengan item_price
#             quantity  item_price
# quantity    1.000000   -0.133936
# item_price -0.133936    1.000000

# %% [markdown]
# ## Profiling Libraries
# profiling data secara otomatis
# ```
# import pandas_profiling
# # function Profile Report untuk dataframe
# pandas_profiling.ProfileReport(dataframe)
# ```
# output yang ditampilkan berupa kayak javascript

# %%
# function Profile Report untuk dataframe
# pandas_profiling.ProfileReport(retail_raw)

# %% [markdown]
# ## Data Cleansing
# - proses mengidentifikasi bagian data yang salah, tidak lengkap, tidak akurat, tidak relevan atau hilang
# - kemudian memodifikasi, mengganti atau menghapusnya sesuai dengan kebutuhan
#
# membahas perlakuan terhadap missing data, perlakuan outliers, sampai deduplikasi data

# %% [markdown]
# ### Missing Data
# missing value itu dapat memengaruhi analisis dan machine learning model
#
# jika menemukan nilai yang hilang dalam dataset, harus melakukan treatment sedemikian rupa
#
# cara check missing value
# ```
# dataframe.isnull().any()
# ```
#
# Cara treatment terhadap missing-value
# - dicuekin, ga diotak atik
# - imputasi, nilai kosong di isi
#   - pengisian menggunakan teknik tertentu
#     - pemanfaatan function fillna dari pandas
#     - menggunakan mean, modus ataupun menggunakan predictive modelling
#
#   ```
#   # mengisi menggunakan nilai rata-rata
#   dataframe['kolom'].fillna(dataframe['kolom'].mean())
#   # mengisi menggunakan nilai yang sering muncul
#   dataframe['kolom'].fillna(dataframe['kolom'].modus())
#   ```
# - hapus row yang mengandung missing value)
#   - menggunakan function dropna dari pandas
#
#   ```
#   # cara menggunakan drop
#   dataframe['kolom'].dropna()
#   ```

# %% [markdown]
# Check kolom yang memiliki missing data, kemudian cetak ke console

# %%
print('Check kolom yang memiliki missing data:')
print(retail_raw.isnull().any())
# Out:
# Check kolom yang memiliki missing data:
# order_id       False
# order_date     False
# customer_id    False
# city            True
# province        True
# product_id      True
# brand          False
# quantity        True
# item_price      True
# dtype: bool

# %% [markdown]
# isi nilai kosong pada kolom quantity dengan nilai rataan (mean)

# %%
print('\nFilling the missing value (imputasi):')
print(retail_raw['quantity'].fillna(retail_raw['quantity'].mean()))
# Out:
# Filling the missing value (imputasi):
# 0       10.0
# 1        2.0
# 2        8.0
# 3        4.0
# 4        2.0
#         ...
# 4995     2.0
# 4996     3.0
# 4997     4.0
# 4998     8.0
# 4999     1.0
# Name: quantity, Length: 5000, dtype: float64

# %% [markdown]
# hapus missing value pada kolom quantity

# %%
print('\nDrop missing value:')
print(retail_raw['quantity'].dropna())
# Out:
# Drop missing value:
# 0       10.0
# 1        2.0
# 2        8.0
# 3        4.0
# 4        2.0
#         ...
# 4995     2.0
# 4996     3.0
# 4997     4.0
# 4998     8.0
# 4999     1.0
# Name: quantity, Length: 4986, dtype: float64

# %% [markdown]
# melengkapi missing value tersebut dengan mean dari item_price

# %%
retail_raw['item_price'].fillna(retail_raw['item_price'].mean())
# Out:
# 0       7.400000e+05
# 1       6.040000e+05
# 2       1.045000e+06
# 3       2.050000e+05
# 4       9.337427e+05
#             ...
# 4995    4.500000e+05
# 4996    1.465000e+06
# 4997    7.470000e+05
# 4998    6.950000e+05
# 4999    1.045000e+06
# Name: item_price, Length: 5000, dtype: float64

# %% [markdown]
# ### Outliers
# merupakan data observasi yang muncul dengan nilai-nilai yang jauh bedanya dengan sebagian besar nilai lainnya
#
# Cara treatment terhadap outliers
# - Remove the outliers (dibuang)
# - Filling the missing value (imputasi)
# - Capping
# - Prediction
#
# outliers dapat ditentukan dengan metric IQR (interquartile range)
# - IQR: Q3 - Q1
# - dapat dikatakan outliers jika memenuhi kedua syarat
#   - < Q1 - 1.5 * IQR
#   - > Q3 + 1.5 * IQR
#
# ```
# # syntax quartile 1 & 3
# q1 = dataframe.quantile(0.25)
# q2 = dataframe.quantile(0.5)
# q3 = dataframe.quantile(0.75)
# # syntax interquartile
# iqr = q3 - q1
# # cara membuang outliers
# dataframe = dataframe[~((dataframe < (q1 - 1.5*iqr)) | (dataframe > (q2 - 1.5*iqr))]
# ```

# %%
# Q1, Q3, dan IQR
Q1 = retail_raw['quantity'].quantile(0.25)
Q3 = retail_raw['quantity'].quantile(0.75)
IQR = Q3 - Q1

# Check ukuran (baris dan kolom) sebelum data yang outliers dibuang
print('Shape awal: ', retail_raw.shape)

# Removing outliers
retail_raw = retail_raw[~((retail_raw['quantity'] < (Q1 - 1.5 * IQR)) | (retail_raw['quantity'] > (Q3 + 1.5 * IQR)))]

# Check ukuran (baris dan kolom) setelah data yang outliers dibuang
print('Shape akhir: ', retail_raw.shape)
# Out:
# Shape awal:  (5000, 9)
# Shape akhir:  (4699, 9)

# %% [markdown]
# mengetahui berapa IQR dari variabel item_price

# %%
# Q1, Q3, dan IQR
Q1 = retail_raw['item_price'].quantile(0.25)
Q3 = retail_raw['item_price'].quantile(0.75)
IQR = Q3 - Q1

# Check ukuran (baris dan kolom) sebelum data yang outliers dibuang
print('Shape awal: ', retail_raw.shape)

# Removing outliers
retail_raw = retail_raw[~((retail_raw['item_price'] < (Q1 - 1.5 * IQR)) | (retail_raw['item_price'] > (Q3 + 1.5 * IQR)))]

# Check ukuran (baris dan kolom) setelah data yang outliers dibuang
print('Shape akhir: ', retail_raw.shape)
# Out:
# Shape awal:  (4699, 9)
# Shape akhir:  (4379, 9)

# %% [markdown]
# ### Deduplikasi Data
# - Duplikasi data, merupakan data dengan kondisi row yang memiliki kesamaan data di seluruh kolomnya
# - Deduplikasi, proses mengatasi dengan menghapus baris yang mengalami duplikasi
#
# ```
# # cara mengecek duplikasi
# dataframe.duplicated(subset=None)
# # cara membuang duplikasi
# dataframe.drop_duplicates()
# ```

# %%
# Check ukuran (baris dan kolom) sebelum data duplikasi dibuang
print('Shape awal: ', retail_raw.shape)

# Buang data yang terduplikasi
retail_raw.drop_duplicates(inplace=True)

# Check ukuran (baris dan kolom) setelah data duplikasi dibuang
print('Shape akhir: ', retail_raw.shape)
# Out:
# Shape awal:  (4379, 9)
# Shape akhir:  (4373, 9)

# %% [markdown]
# # Mini Project

# %% [markdown]
# ## Data Profiling Case Study
# menggunakan dataset csv bernama uncleaned_raw
#
# cek kolom yang terdapat missing value, kemudian isi missing value dengan hasil mean dari kolom tersebut

# %%
# Baca dataset uncleaned_raw.csv
uncleaned_raw = pd.read_csv('https://dqlab-dataset.s3-ap-southeast-1.amazonaws.com/uncleaned_raw.csv')

#inspeksi dataframe uncleaned_raw
print('Lima data teratas:') 
print(uncleaned_raw.head())

#Check kolom yang mengandung missing value
print('\nKolom dengan missing value:') 
print(uncleaned_raw.isnull().any())

#Persentase missing value
length_qty = len(uncleaned_raw['Quantity'])
count_qty = uncleaned_raw['Quantity'].count()

#mengurangi length dengan count
number_of_missing_values_qty = length_qty - count_qty

#mengubah ke bentuk float
float_of_missing_values_qty = float(number_of_missing_values_qty / length_qty) 

#mengubah ke dalam bentuk persen
pct_of_missing_values_qty = '{0:.1f}%'.format(float_of_missing_values_qty*100) 

#print hasil percent dari missing value
print('Persentase missing value kolom Quantity:', pct_of_missing_values_qty)

#Mengisi missing value tersebut dengan mean dari kolom tersebut
uncleaned_raw['Quantity'] = uncleaned_raw['Quantity'].fillna(uncleaned_raw['Quantity'].mean())
# Out:
# Lima data teratas:
#    InvoiceNo                          Description  ...  CustomerID      City
# 0     536365   WHITE HANGING HEART T-LIGHT HOLDER  ...       17850  Surabaya
# 1     536366                  WHITE METAL LANTERN  ...       17850  Surabaya
# 2     536367       CREAM CUPID HEARTS COAT HANGER  ...       17850  Surabaya
# 3     536368  KNITTED UNION FLAG HOT WATER BOTTLE  ...       17850   Jakarta
# 4     536369       RED WOOLLY HOTTIE WHITE HEART.  ...       17850     Medan
#
# [5 rows x 7 columns]
#
# Kolom dengan missing value:
# InvoiceNo      False
# Description    False
# Quantity        True
# InvoiceDate    False
# UnitPrice      False
# CustomerID     False
# City           False
# dtype: bool
# Persentase missing value kolom Quantity: 4.0%

# %% [markdown]
# ## Data Cleansing Case Study
# cari tau kolom yang terdapat outliers, kemudian gunakan visualisasi dengan boxplot pada dataframe uncleaned_raw

# %%
import matplotlib.pyplot as plt

#Mengetahui kolom yang memiliki outliers!
uncleaned_raw.boxplot()
plt.show()

# %% [markdown]
# Melakukan proses removing outliers pada kolom UnitPrice
#
# kemudian cek duplikasi and dataset tersebut di deduplikasi

# %%
#Check IQR
Q1 = uncleaned_raw['UnitPrice'].quantile(0.25)
Q3 = uncleaned_raw['UnitPrice'].quantile(0.75)
IQR = Q3 - Q1

#removing outliers
uncleaned_raw = uncleaned_raw[~((uncleaned_raw[['UnitPrice']] < (Q1 - 1.5 * IQR)) | (uncleaned_raw[['UnitPrice']] > (Q3 + 1.5 * IQR)))]

#check for duplication
print(uncleaned_raw.duplicated(subset=None))

#remove duplication
uncleaned_raw = uncleaned_raw.drop_duplicates()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 500     True
# 501     True
# 502     True
# 503     True
# 504     True
# Length: 505, dtype: bool
