# %% [markdown]
# # memanipulasi list, tuple, set, dictionary dan string pada Python

# %% [markdown]
# ## Collection Manipulation dengan Python

# %% [markdown]
# ### Set Manipulation
# *   .union(), penggabungan 2 set (union)
# *   .isdisjoint(), mengembalikan nilai True kalau disjoint atau saling lepas dengan setnya
# *   .issubset(), mengembalikan nilai True kalau set tersebut merupakan subset dari set yang lain
# *   .issuperset(), mengembalikan nilai True kalau set tersebut merupakan superset dari set yang lain
# *   .intersection(), mengembalikan nilai yang terdapat di kedua set yang intersection
# *   .difference(), mengembalikan nilai dari set yang tidak terdapat pada set seberang
# *   .symmetric_difference(), mengembalikan nilai dari set yang apabila digabungkan (union). dimana nilai setnya merupakan kebalikan dari intersection

# %%
# Fitur .union()
print(">>> Fitur .union()")
parcel1 = {'Anggur','Apel','Jeruk'}
parcel2 = {'Apel','Kiwi','Melon'}
parcel3 = parcel1.union(parcel2)
print("parcel 1 :", parcel1)
print("parcel 3 :", parcel3)
# Fitur .isdisjoint()
print(">>> Fitur .isdisjoint()")
parcel1 = {'Anggur','Apel','Jeruk'}
parcel2 = {'Kiwi','Melon','Pisang'}
parcel3 = {'Apel','Srikaya','Semangka'}
parcel1_parcel2_disjoint = parcel1.isdisjoint(parcel2)
print("parcel 1 disjoint dengan parcel 2 : ", parcel1_parcel2_disjoint)
parcel1_parcel3_disjoint = parcel1.isdisjoint(parcel3)
print("parcel 1 disjoint dengan parcel 3 : ", parcel1_parcel3_disjoint)
# Fitur .issubset()
print(">>> Fitur .issubset()")
parcel_A = {'Anggur', 'Apel'}
parcel_B = {'Durian','Semangka','Apel'}
parcel_C = {'Anggur', 'Kiwi', 'Apel', 'Jeruk', 'Melon'}
print("parcel A :", parcel_A)
print("parcel B :", parcel_B)
print("parcel C :", parcel_C)
parcel_A_dalam_C = parcel_A.issubset(parcel_C)
parcel_B_dalam_C = parcel_B.issubset(parcel_C)
print("parcel A dalam parcel C : ", parcel_A_dalam_C)
print("parcel B dalam parcel C : ", parcel_B_dalam_C)
# Fitur .issuperset()
print(">>> Fitur .issuperset()")
parcel_C_mengandung_A = parcel_C.issuperset(parcel_A)
parcel_C_mengandung_B = parcel_C.issuperset(parcel_B)
print("parcel C mengandung parcel A : ", parcel_C_mengandung_A)
print("parcel C mengandung parcel B : ", parcel_C_mengandung_B)
# Fitur .intersection()
print(">>> Fitur .intersection()")
parcel_A = {'Anggur', 'Kiwi', 'Apel', 'Jeruk', 'Melon'}
parcel_B = {'Apel', 'Jeruk', 'Semangka', 'Durian', 'Tomat'}
print("parcel A :", parcel_A)
print("parcel B :", parcel_B)
parcel_C = parcel_A.intersection(parcel_B)
print("parcel C : ", parcel_C)
# Fitur .difference()
print(">>> Fitur .difference()")
parcel_C = parcel_A.difference(parcel_B)
print("parcel C : ", parcel_C)
# Fitur .symmetric_difference()
print(">>> Fitur .symmetric_difference()")
parcel_A = {'Anggur', 'Apel', 'Jeruk', 'Melon'}
parcel_B = {'Apel','Jeruk','Semangka','Leci'}
print("parcel A :", parcel_A)
print("parcel B :", parcel_B)
parcel_C = parcel_A.symmetric_difference(parcel_B)
print("parcel C : ",parcel_C)
# Out:
# >>> Fitur .union()
# parcel 1 : {'Jeruk', 'Apel', 'Anggur'}
# parcel 3 : {'Jeruk', 'Melon', 'Kiwi', 'Apel', 'Anggur'}
# >>> Fitur .isdisjoint()
# parcel 1 disjoint dengan parcel 2 :  True
# parcel 1 disjoint dengan parcel 3 :  False
# >>> Fitur .issubset()
# parcel A : {'Apel', 'Anggur'}
# parcel B : {'Semangka', 'Apel', 'Durian'}
# parcel C : {'Jeruk', 'Kiwi', 'Apel', 'Melon', 'Anggur'}
# parcel A dalam parcel C :  True
# parcel B dalam parcel C :  False
# >>> Fitur .issuperset()
# parcel C mengandung parcel A :  True
# parcel C mengandung parcel B :  False
# >>> Fitur .intersection()
# parcel A : {'Jeruk', 'Kiwi', 'Apel', 'Melon', 'Anggur'}
# parcel B : {'Jeruk', 'Semangka', 'Apel', 'Durian', 'Tomat'}
# parcel C :  {'Jeruk', 'Apel'}
# >>> Fitur .difference()
# parcel C :  {'Melon', 'Kiwi', 'Anggur'}
# >>> Fitur .symmetric_difference()
# parcel A : {'Jeruk', 'Melon', 'Apel', 'Anggur'}
# parcel B : {'Jeruk', 'Semangka', 'Apel', 'Leci'}
# ...

# %% [markdown]
# ### Dictionary Manipulation
# * .clear(), menghapus semua elemen dalem dictionary
# * .copy(), menduplikasi atau mengembalikan copy dari semua elemen dalem dictionary
# * .keys(), mengembalikan seluruh elemen berdasarkan kunci akses (keys)
# * .values(), mengembalikan list dari seluruh value dari setiap elemen
# * .update(), menambahkan kunci akses (keys) dan valuenya ke dalam dictionary

# %%
# Fitur .clear()
print(">>> Fitur .clear()")
info_karyawan = {'nama' : 'Aksara',
                 'nik' : '1211011',
                 'pekerjaan' : 'Data Analyst'}
info_karyawan.clear()
print("info karyawan : ", info_karyawan)
# Fitur .copy()
print(">>> Fitur .copy()")
info_karyawan1 = {'nama' : 'Aksara',
                  'nik' : '1211011',
                  'pekerjaan' : 'Data Analyst'}
info_karyawan2 = info_karyawan1.copy()
info_karyawan2['nama'] = 'Senja'
info_karyawan2['nik'] = '1211056'
print("info karyawan 1 : ", info_karyawan1)
print("info karyawan 2 : ", info_karyawan2)
# Fitur .keys()
print(">>> Fitur .keys()")
info_karyawan = {'nama' : 'Aksara',
                 'nik' : '1211011',
                 'pekerjaan' : 'Data Analyst'}
kunci_akses = list(info_karyawan.keys())
print("kunci akses : ", kunci_akses)
# Fitur .values()
print(">>> Fitur .values()")
value_dict = list(info_karyawan.values())
print("value dict : ", value_dict)
# Fitur .update()
print(">>> Fitur .update()")
info_karyawan.update({'skillset':['Python', 'R']})
print("info karyawan : ", info_karyawan)
# Out:
# >>> Fitur .clear()
# info karyawan :  {}
# >>> Fitur .copy()
# info karyawan 1 :  {'nama': 'Aksara', 'nik': '1211011', 'pekerjaan': 'Data Analyst'}
# info karyawan 2 :  {'nama': 'Senja', 'nik': '1211056', 'pekerjaan': 'Data Analyst'}
# >>> Fitur .keys()
# kunci akses :  ['nama', 'nik', 'pekerjaan']
# >>> Fitur .values()
# value dict :  ['Aksara', '1211011', 'Data Analyst']
# >>> Fitur .update()
# info karyawan :  {'nama': 'Aksara', 'nik': '1211011', 'pekerjaan': 'Data Analyst', 'skillset': ['Python', 'R']}

# %% [markdown]
# penerapan fungsi built-in len
# * fungsi len digunakan untuk menampilkan jumlah elemen dalam tuple atau list
#
#
# set, kumpulan elemen yang tersusun yang tidak terurut
#
# list, kumpulan elemen yang tersusun yang terurut

# %%
# Tuple
print(">>> Tuple")
tuple_menu = ('Gado-gado','Ayam Goreng','Rendang','Ketoprak')
jumlah_menu = len(tuple_menu)
print("jumlah menu : ", jumlah_menu)
# List
print(">>> List")
list_menu = ['Gado-gado','Ayam Goreng','Rendang','Ketoprak']
jumlah_menu = len(list_menu)
print("jumlah menu : ", jumlah_menu)
# Konversi tipe data
print(">>> Konversi tipe data")
list_buah = ['Apel', 'Apel', 'Jeruk', 'Markisa', 'Jeruk', 'Markisa', 'Apel']
# diubah jadi set
set_buah = set(list_buah)
print("set buah : ", set_buah)
list_buah = list(set_buah)
list_buah.sort()
print("list buah : ", list_buah)
# Out:
# >>> Tuple
# jumlah menu :  4
# >>> List
# jumlah menu :  4
# >>> Konversi tipe data
# set buah :  {'Jeruk', 'Markisa', 'Apel'}
# list buah :  ['Apel', 'Jeruk', 'Markisa']

# %% [markdown]
# ### Tugas Praktek

# %%
# Data keuangan
keuangan = {
'pengeluaran': [2, 2.5, 2.25, 2.5, 3.2, 2.5, 3.5, 4, 3],
'pemasukan': [7.8, 7.5, 9, 7.6, 7.2, 7.5, 7, 10, 7.5]
}
# Perhitungan rata-rata pemasukan dan rata-rata pengeluaran
total_pengeluaran = 0
total_pemasukan = 0
# di hitung dalam pengeluaran dengan index iterasi "biaya"
for biaya in keuangan['pengeluaran']: 
    total_pengeluaran += biaya
for pendapatan in keuangan['pemasukan']: 
    total_pemasukan += pendapatan 
# rata - rata pengeluaran = total pengeluaran / frekuensi biaya
rata_rata_pengeluaran = total_pengeluaran / len(keuangan['pengeluaran'])
rata_rata_pemasukan = total_pemasukan / len(keuangan['pemasukan'])
print(rata_rata_pengeluaran) 
print(rata_rata_pemasukan)
# Out:
# 2.8277777777777775
# 7.8999999999999995

# %% [markdown]
# ## String Manipulation
# teknik yang digunakan dalam memanipulasi data yang disimpan dalam tipe data str
#
# untuk mempermudah proses pengolahan data, tipe data string dapat diperlakukan layaknya seperti tipe data list

# %%
nama_produk = "Sepatu Niko"
nama_produk = nama_produk[:2] + "P" + nama_produk[3:9] + "K" + nama_produk[-1]
# menghasilkan output SePatu NiKo
print(nama_produk)
# menghasilkan output SePatu
print(nama_produk[:7])
# menghasilkan output NiKo
print(nama_produk[7:])
# menghasilkan output 11
print(len(nama_produk))
# Out:
# SePatu NiKo
# SePatu
# NiKo
# 11

# %% [markdown]
# ### Operator "+" untuk tipe data string
# *  Operator + pada dua string menggabungkan kedua string tersebut
# *  juga dapat digunakan untuk menambahkan beberapa string secara  sekaligus

# %%
# inisasi
nama_depan = 'John'
nama_belakang = 'Doee'

# buat variabel nama lengkap dengan operator +
nama_lengkap = nama_depan + ' ' + nama_belakang
print(nama_lengkap)

umur = '27 tahun'
alamat = 'Jl. Anggrek No. 100'

# buat kalimat dengan gabungan string +
nama_umur_alamat = 'Hi, saya ' + nama_lengkap + ' umur ' + umur + ', tinggal di ' + alamat + '.'
print(nama_umur_alamat)
# Out:
# John Doee
# Hi, saya John Doee umur 27 tahun, tinggal di Jl. Anggrek No. 100.

# %% [markdown]
# ### Menghilangkan Spasi di Awal atau di Akhir
# *   .strip(), menghilangkan kelebihan spasi pada awal dan akhir string.
# *   .lstrip(), menghilangkan kelebihan spasi pada awal string.
# *   .rstrip(), menghilangkan kelebihan spasi pada akhir string.

# %%
# Fitur .strip()
print(">>> Fitur .strip()")
kata_sambutan = ' halo, selamat siang!   '
kata_sambutan = kata_sambutan.strip()
print(kata_sambutan)

# Fitur .lstrip()
print(">>> Fitur .lstrip()")
kata_sambutan = ' halo, selamat siang!   '
kata_sambutan = kata_sambutan.lstrip()
print(kata_sambutan)

# Fitur .rstrip()
print(">>> Fitur .rstrip()")
kata_sambutan = ' halo, selamat siang!   '
kata_sambutan = kata_sambutan.rstrip()
print(kata_sambutan)
# Out:
# >>> Fitur .strip()
# halo, selamat siang!
# >>> Fitur .lstrip()
# halo, selamat siang!
# >>> Fitur .rstrip()
#  halo, selamat siang!

# %% [markdown]
# ### Merubah Caps pada String
# *   .capitalize(), mengubah elemen pertama pada string jadi kapital
# *   .lower(), mengubah seluruh elemen string jadi huruf kecil
# *   .upper(), mengubah seluruh elemen string jadi huruf kapital

# %%
# Fitur .capitalize()
print(">>> Fitur .capitalize()")
judul_buku = 'belajar bahasa Python'
print(judul_buku.capitalize())

# Fitur .lower()
print(">>> Fitur .lower()")
judul_buku = 'Belajar Bahasa PYTHON.'
print(judul_buku.lower())

# Fitur .upper()
print(">>> Fitur .upper()")
judul_buku = 'Belajar Bahasa PYTHON.'
print(judul_buku.upper())
# Out:
# >>> Fitur .capitalize()
# Belajar bahasa python
# >>> Fitur .lower()
# belajar bahasa python.
# >>> Fitur .upper()
# BELAJAR BAHASA PYTHON.

# %% [markdown]
# ### Pemecahan, Penggabungan, dan Penggantian String
# *   .split(), memecah sebuah string berdasarkan string lain jadi list baru
# *   .join(), gabungin list yang berisi string dengan string lain
# *   .replace(), menggantikan kemunculan suatu string tertentu pada string tersebut

# %%
# Fitur .split()
print(">>> Fitur .split()")
bilangan = "ani dan budi dan wati dan johan"
karakter = bilangan.split("dan")
print(karakter)
kata = bilangan.split(" ")

print(kata)
# Fitur .join()
print(">>> Fitur .join()")
pemisah = " dan "
karakter = ["Ricky", "Peter", "Jordan"]
kalimat = pemisah.join(karakter)
print(kalimat)
kalimat = " ".join(karakter)
print(kalimat)

# Fitur .replace()
print(">>> Fitur .replace()")
kalimat = "apel malang apel yang paling segar, apel sehat, apel nikmat"
# replace(<kalimat_lama>, <kalimat_baru>)
kalimat = kalimat.replace("apel", "jeruk")
print(kalimat)
# Out:
# >>> Fitur .split()
# ['ani ', ' budi ', ' wati ', ' johan']
# ['ani', 'dan', 'budi', 'dan', 'wati', 'dan', 'johan']
# >>> Fitur .join()
# Ricky dan Peter dan Jordan
# Ricky Peter Jordan
# >>> Fitur .replace()
# jeruk malang jeruk yang paling segar, jeruk sehat, jeruk nikmat

# %% [markdown]
# ### Menentukan Posisi dan Jumlah Sub-string pada String
# *   .find(), mencari salah satu elemen tertentu pada string
# *   .count(), menghitung jumlah kemunculan teks string dalam string yang dicari (bersifat case sensitive)

# %%
teks = "Apel malang adalah apel termanis dibanding apel-apel lainnya"

# Fitur .find()
print(">>> Fitur .find()")
print(teks.find("Apel"))
print(teks.find("malang"))

# Fitur .count()
print(">>> Fitur .count()")
kemunculan_kata_apel = teks.count("apel")
print(kemunculan_kata_apel)
# Out:
# >>> Fitur .find()
# 0
# 5
# >>> Fitur .count()
# 3

# %% [markdown]
# ### Menentukan String Apakah Diawali/Diakhiri oleh Sub-string
# *   .startswith(), mengembalikan nilai true kalau teks diawali dengan teks yang lain
# *   .endswith(), mengembalikan nilai true kalau teks diakhiri dengan teks yang lain

# %%
# Fitur .startswith()
print(">>> Fitur .startswith()")
teks = "Apel malang adalah apel termanis dibanding apel-apel lainnya"
print(teks.startswith("Apel"))
print(teks.startswith("apel"))

# Fitur .endswith()
print(">>> Fitur .endswith()")
print(teks.endswith("lainnya"))
print(teks.endswith("apel"))
# Out:
# >>> Fitur .startswith()
# True
# False
# >>> Fitur .endswith()
# True
# False

# %% [markdown]
# ### Tugas Praktek 1

# %%
judul_artikel = [
"Buah Salak Baik untuk Mata", "Buah Salak Kaya Potasium", 
"Buah Jeruk Kaya Vitamin C", "Buah Salak Kaya Manfaat", 
"Salak Baik untuk Jantung", "Jeruk dapat Memperkuat Tulang", 
"Jeruk Mencegah Penyakit Asma", "Jeruk Memperkuat Gigi", 
"Jeruk Mencegah Kolesterol Jahat", "Salak Mencegah Diabetes", 
"Salak Memperkuat Dinding Usus", "Salak Baik untuk Darah",
"Jeruk Kaya Manfaat untuk Jantung", "Salak si Kecil yang Baik", 
"Jeruk dan Salak Buah Kaya Manfaat", "Buah Jeruk Enak",
"Tips Panen Jeruk Ribuan Kilo", "Tips Bertanam Salak", 
"Salak Manis untuk Berbuka", "Jeruk Baik untuk Wajah"
]

jumlah_artikel_jeruk = 0
jumlah_artikel_salak = 0
for judul in judul_artikel:
    if judul.count("Jeruk") > 0: 
        jumlah_artikel_jeruk += 1
    if judul.count("Salak") > 0:
        jumlah_artikel_salak += 1
print(jumlah_artikel_jeruk) 
print(jumlah_artikel_salak)
# Out:
# 10
# 11

# %% [markdown]
# ### Tugas Praktek 2

# %%
judul_artikel = [
"Buah Salak Baik untuk Mata", "Buah Salak Kaya Potasium", 
"Buah Jeruk Kaya Vitamin C", "Buah Salak Kaya Manfaat", 
"Salak Baik untuk Jantung", "Jeruk dapat Memperkuat Tulang", 
"Jeruk Mencegah Penyakit Asma", "Jeruk Memperkuat Gigi", 
"Jeruk Mencegah Kolesterol Jahat", "Salak Mencegah Diabetes", 
"Salak Memperkuat Dinding Usus", "Salak Baik untuk Darah",
"Jeruk Kaya Manfaat untuk Jantung", "Salak si Kecil yang Baik", 
"Jeruk dan Salak Buah Kaya Manfaat", "Buah Jeruk Enak",
"Tips Panen Jeruk Ribuan Kilo", "Tips Bertanam Salak", 
"Salak Manis untuk Berbuka", "Jeruk Baik untuk Wajah"
]

kata_positif = ["Kaya", "Baik", "Mencegah", "Memperkuat"]
kata_positif_jeruk = 0
kata_positif_salak = 0
for judul in judul_artikel: 
    for kata in kata_positif:
        if judul.count("Jeruk") > 0 and judul.count(kata) > 0: 
            kata_positif_jeruk += 1
        if judul.count("Salak") > 0 and judul.count(kata) > 0:
            kata_positif_salak += 1
print(kata_positif_jeruk) 
print(kata_positif_salak)
# Out:
# 8
# 9

# %% [markdown]
# ## Functions
# blok statemen yang dijalankan saat dipanggi
# ```
# # contoh function
# def nama_fungsi(argument):
#     statement_1
#     …
#     statement_n
#     return returned_value
# ```
# *   nama_fungsi, nama fungsi yang ditentukan sama seperti halnya variabel
# *   argument, variabel masukan ke fungsi (bersifat opsional)
# *   statement_1 … statement_n, pernyataan berdasarkan kondisi atau looping sesuai yang ditentukan
# *   return_value, variabel output dari fungsi

# %%
# Definisikan fungsi
def contoh_fungsi():
    print("Halo Dunia")
    print("Aku sedang belajar bahasa Python")
    
# Panggil fungsi yang telah didefinisikan
contoh_fungsi()
# Out:
# Halo Dunia
# Aku sedang belajar bahasa Python

# %% [markdown]
# ### Fungsi dengan menerima argument
# menerima serangkaian argumen pada bagian dalam kurung setelah di definisikan

# %%
# Definsikan fungsi 
def fungsi_dengan_argumen(nama_depan, nama_belakang):
    print(nama_depan + " " + nama_belakang)
# Panggil fungsi dengan memasukkan argumen
# nama_depan yaitu "John" dan nama_belakang "Doe"
fungsi_dengan_argumen("John", "Doe")
# Out:
# John Doe

# %% [markdown]
# ### Fungsi dengan nilai default
# terdapat nilai default pada salah satu argumennya, sehingga suatu argumen dalam sebuah fungsi akan bersifat opsional.

# %%
# Definsikan fungsi dengan nilai default argument kedua adalah "".
def fungsi_dengan_argumen(nama_depan, nama_belakang = " "):
	print(nama_depan + " " + nama_belakang)
 
# Panggil fungsi dengan memasukkan argumen nama_depan "John"
fungsi_dengan_argumen("John")

# Panggil fungsi dengan memasukkan argumen
# nama_depan yaitu "John" dan nama_belakang "Doe"
fungsi_dengan_argumen("John", "Doe")
# Out:
# John
# John Doe

# %% [markdown]
# ### Tugas Praktek 1
# menghitung rata - rata data dengan function

# %%
# Dua buah data yang tersimpan dalam tipe list
data1 = [70, 70, 70, 100, 100, 100, 120, 120, 150, 150]
data2 = [50, 60, 60, 50, 70, 70, 100, 80, 100, 90]

# Definisikan fungsi hitng_rata_rata
def hitung_rata_rata(data):
    # inisiasi untuk menampung jumlah iterasi
    jumlah = 0
    # perulangan item perdata yang diinput
    for item in data:
        # jumlah data bertambah setelah diitung dengan perulangan
        jumlah += item
    # rata - rata = jumlah data / banyaknya data
    rata_rata = jumlah/len(data)
    return rata_rata

# Hitung nilai rata-rata dari kedua data yang dimiliki
print('Rata-rata data1:')
print(hitung_rata_rata(data1))
print('Rata-rata data2:')
print(hitung_rata_rata(data2))
# Out:
# Rata-rata data1:
# 105.0
# Rata-rata data2:
# 73.0

# %% [markdown]
# ### Tugas Praktek 1
# menghitung rata - rata data dengan function, kemudian dilengkapi dengan standar deviasi

# %%
# Dua buah data yang tersimpan dalam tipe list
data1 = [70, 70, 70, 100, 100, 100, 120, 120, 150, 150]
data2 = [50, 60, 60, 50, 70, 70, 100, 80, 100, 90]

# Definisikan fungsi hitng_rata_rata
def hitung_rata_rata(data):
    # inisiasi untuk menampung jumlah iterasi
    jumlah = 0
    # perulangan item perdata yang diinput
    for item in data:
        # jumlah data bertambah setelah diitung dengan perulangan
        jumlah += item
    # rata - rata = jumlah data / banyaknya data
    rata_rata = jumlah/len(data)
    return rata_rata

# Definisikan fungsi hitung_standar_deviasi
def hitung_standar_deviasi(data):
    # nilai rata - rata diambil dari fungsi data
    rata_rata_data = hitung_rata_rata(data)
    varians = 0
    # perulangan item perdata yang diinput
    for item in data:
        # varians merupakan jumlah item yang di masing - masing di kurang rata-rata dibagi 2
        varians += (item - rata_rata_data) ** 2
        # kemudian varians dibagi oleh banyak datanya
        varians /= len(data)
    # standar deviasi merupakan hasil dari akar pada varians
    standar_deviasi = varians ** (1/2)
    return standar_deviasi

# Hitung nilai standar deviasi dari kedua data yang dimiliki
print('Standar deviasi data1:')
print(hitung_standar_deviasi(data1))
print('Standar deviasi data2:')
print(hitung_standar_deviasi(data2))
# Out:
# Standar deviasi data1:
# 14.93311056335886
# Standar deviasi data2:
# 6.025948374480153

# %% [markdown]
# ### Tugas Praktek 1
# menghitung rata - rata data dengan function, kemudian dilengkapi dengan standar deviasi
#
# pada data yang menggunakan dict

# %%
# Data properti
tabel_properti = {
'luas_tanah': [70, 70, 70, 100, 100, 100, 120, 120, 150, 150],
'luas_bangunan': [50, 60, 60, 50, 70, 70, 100, 80, 100, 90],
'jarak': [15, 30, 55, 30, 25, 50, 20, 50, 50, 15],
'harga': [500, 400, 300, 700, 1000, 650, 2000, 1200, 1800, 3000]
}

# Fungsi rata-rata data
def hitung_rata_rata(data):
    jumlah = 0
    for item in data:
        jumlah += item
    rata_rata = jumlah/len(data)
    return rata_rata

# Fungsi hitung_standar_deviasi
def hitung_standar_deviasi(data):
    rata_rata_data = hitung_rata_rata(data)
    varians = 0
    for item in data:
        varians += (item - rata_rata_data) ** 2
        varians /= len(data)
    standar_deviasi = varians ** (1/2)
    return standar_deviasi

# Definisikan fungsi untuk menghitung rata-rata dan standar deviasi
# setiap kolom pada tabel_properti yang diberikan oleh key dict.
def deskripsi_properti(tabel):
    # memanggil fungsi keys untuk mengakses key pada dict 
    for key in tabel.keys():
        print('Rata-rata ' + key + ':')
        print(hitung_rata_rata(tabel[key])) 
        print('Standar deviasi ' + key + ':')
        print(hitung_standar_deviasi(tabel[key]))
        print('')

# Panggil fungsi deskripsi_properti untuk menghitung rata-rata 
# dan standar deviasi setiap kolom pada tabel_properti
deskripsi_properti(tabel_properti)
# Out:
# Rata-rata luas_tanah:
# 105.0
# Standar deviasi luas_tanah:
# 14.93311056335886
#
# Rata-rata luas_bangunan:
# 73.0
# Standar deviasi luas_bangunan:
# 6.025948374480153
#
# Rata-rata jarak:
# 34.0
# Standar deviasi jarak:
# 6.24005184770928
#
# Rata-rata harga:
# 1155.0
# Standar deviasi harga:
# 587.0594351517378

# %% [markdown]
# ## Manipulasi berkas teks
#
# *   menggunakan fungsi open() untuk membuka/ membuat berkas teks
#
#     ```
#     # open(<parameter1>, <parameter2>)
#     file = open("hello.txt", "r")
#     ```
#     *   parameter1 , nama dari file
#     *   parameter2 , mode untuk membuka (dengan "r" atau read),  membuat (dengan "w" atau write), menambah isi file (dengan "a" atau append), membaca dan menuliskan isi file (dengan "w+" atau write+), membaca dan menambahkan isi file (dengan "a+" atau append+)
# *   terus menutup file dengan fungsi close()

# %% [markdown]
# ### Membaca Berkas Teks

# %%
# Membaca file hello.txt dengan fungsi read()
print(">>> Membaca file hello.txt dengan fungsi read()")
file = open("hello.txt", "r")
# file yang dibaca ditampung pada variabel content
content =file.read()
# setelah di baca, file ditutup dengan close
file.close()
# print isi kontennya
print(content)

# Membaca file hello.txt dengan fungsi readline()
print(">>> Membaca file hello.txt dengan fungsi readline()")
file = open("hello.txt", "r")
# readline untuk membaca secara baris per baris
first_line = file.readline()
second_line = file.readline()
# setelah di baca, file ditutup dengan close
file.close()
print(first_line)
print(second_line)
# Out:
# >>> Membaca file hello.txt dengan fungsi read()
# Kita sedang belajar Python
# Tepatnya belajar memanipulasi berkas teks
# Memanipulasi berkas dengan Python sangatlah mudah!
# >>> Membaca file hello.txt dengan fungsi readline()
# Kita sedang belajar Python
#
# Tepatnya belajar memanipulasi berkas teks

# %% [markdown]
# terdapat fungsi readlines yang mengembalikan list tiap baris elemennya pada berkas teks

# %%
# Membaca file hello.txt dengan fungsi readlines()
print(">>> Membaca file hello.txt dengan fungsi readlines()")
file = open("hello.txt", "r")
all_lines = file.readlines()
file.close()
print(all_lines)

# Membaca file hello.txt dengan menerapkan looping
print(">>> Membaca file hello.txt dengan menerapkan looping")
file = open("hello.txt", "r")
for line in file:
    print(line)
# Out:
# >>> Membaca file hello.txt dengan fungsi readlines()
# ['Kita sedang belajar Python\n', 'Tepatnya belajar memanipulasi berkas teks\n', 'Memanipulasi berkas dengan Python sangatlah mudah!']
# >>> Membaca file hello.txt dengan menerapkan looping
# Kita sedang belajar Python
#
# Tepatnya belajar memanipulasi berkas teks
#
# Memanipulasi berkas dengan Python sangatlah mudah!

# %% [markdown]
# ### Menulis Berkas Teks
# *   write(), menulis biasa
# *   writelines(),
#
# kalau langsung pake "w" maka akan menghapus seluruh isi dalam berka

# %%
# membuka file
file = open("hello.txt", "w")

# menulis ke file hello_write.txt
file.write("Sekarang kita belajar menulis dengan menggunakan Python")
file.write("Menulis konten file dengan mode w (write).")

# menutup file
file.close()

# %% [markdown]
# ### menulis dengan mode append
# menulis file tanpa menghapus isi teks sebelumnya

# %%
# Menulis ke file dengan mode append
file = open("hello.txt", "a")
file.writelines([
"Sekarang kita belajar menulis dengan menggunakan Python", 
"Menulis konten file dengan mode a (append)"
])
file.close()

# %% [markdown]
# ### Library Matematika pada Python
# memanggil library python dengan "import"
# ```
# # memanggil lirbary
# import <library>
# ```
# memanggil lirbary math dari python
#
# agar dapat menjalankan operasi matematika
#
#
# ```
# # import library untuk matematis
# import math
# ```

# %% [markdown]
# ### Fungsi dalam Library Matematika
# *   math.ceil(), menerima input angka, kemudian dikembalikan dengan pembulatan ke atas.
# *   math.floor(), menerima input angka, kemudian dikembalikan dengan pembulatan ke bawah
# *   math.fabs(), menerima input angka, kemudian dikembalikan dengan hasil absolut (tidak ada positif negatif)
# *   math.factorial(), menerima input angka, kemudian dikembalikan dengan hasil faktorial dari angka yang diinput
# *   math.fsum(), menerima input tipe data collection (tuple, list, etc.), kemudian dikembalikan dengan hasil penjumlahannya

# %%
# Import library math
import math

# Fungsi math.ceil()
print(">>> Fungsi math.ceil()")
x = 10.32
y = 13.87
x_ceil = math.ceil(x)
y_ceil = math.ceil(y)
print(x_ceil)
print(y_ceil)

# Fungsi math.floor()
print(">>> Fungsi math.floor()")
x_floor = math.floor(x)
y_floor = math.floor(y)
print(x_floor)
print(y_floor)

# Fungsi math.fabs()
print(">>> Fungsi math.fabs()")
x = 10.32
y = -13.87
x = math.fabs(x)
y = math.fabs(y)
print(x)
print(y)

# Fungsi math.factorial()
print(">>> Fungsi math.factorial()")
x_factorial = math.factorial(5)
print(x_factorial)

# Fungsi math.fsum()
print(">>> Fungsi math.fsum()")
x = [1, 2, 3, 4, 5, 6, -6, -5, -4]
total = math.fsum(x)
print(total)
# Out:
# >>> Fungsi math.ceil()
# 11
# 14
# >>> Fungsi math.floor()
# 10
# 13
# >>> Fungsi math.fabs()
# 10.32
# 13.87
# >>> Fungsi math.factorial()
# 120
# >>> Fungsi math.fsum()
# 6.0

# %% [markdown]
# *  math.log(), menerima input 2 angka, kemudian dikembalikan dengan hasil logaritma.
# ```
# # logaritma
# math.log(<bilangan hasil kuadrat>, <bilangan dasar>)
# ```
# *  math.sqrt(), menerima input angka, kemudian dikembalikan dengan hasil akar pangkat dua
# ```
# # logaritma
# math.sqrt(<masukan angka>)
# ```
# *  math.copysign(), mengembalikan tanda bilangan pertama yang dikalikan dengan tanda positif/ negatif dari bilangan kedua
# ```
# # logaritma
# math.copysign(<bilangan pertama>, <bilangan kedua>)
# ```

# %%
# Import library math
import math

# Fungsi math.log()
print(">>> Fungsi math.log()")
# x = log basis 2 dari 8
x = math.log(8, 2)
# y = log basis 3 dari 81
y = math.log(81, 3)
# z = log basis 10 dari 10000
z = math.log(10000, 10)
print(x)
print(y)
print(z)

# Fungsi math.sqrt()
print(">>> Fungsi math.sqrt()")
# akar kuadrat dari 100
x = math.sqrt(100)
print(x)
# akar kuadrat dari 2
y = math.sqrt(2)
print(y)

# Fungsi math.copysign()
print(">>> Fungsi math.copysign()")
x = 10.32
y = -13.87
z = -15
x = math.copysign(x, z)
y = math.copysign(y, z)
z = math.copysign(z, 10)
print(x)
print(y)
print(z)
# Out:
# >>> Fungsi math.log()
# 3.0
# 4.0
# 4.0
# >>> Fungsi math.sqrt()
# 10.0
# 1.4142135623730951
# >>> Fungsi math.copysign()
# -10.32
# -13.87
# 15.0

# %% [markdown]
# Quiz math.ceil dalam function

# %%
import math
x = [2.22,-3.33,4.44,-5.55]
total = 0
for i in x:
    total += math.ceil(i)
print(total)
# Out:
# 0

# %% [markdown]
# ### Tugas Praktek
# mengembangkan model prediksi harga rumah berdasarkan luas tanah, luas bangunan serta kedekatan lokasi
#
# Langkah 1
# * membaca file harga_rumah.txt
# * ditampilkan setiap data ke dalam tipe data dictionary
# * menampung keseluruhan data dalam sebuah list bernama harga_rumah

# %%
# Baca file "harga_rumah.txt"
file_harga_rumah = open("harga_rumah.txt", "r")
data_harga_rumah = file_harga_rumah.readlines()
# kemudian ditutup filenya
file_harga_rumah.close()

# Buat list of dict dengan nama harga rumah
key_harga_rumah = data_harga_rumah[0].replace("\n","").split(",")
# inisiasi variabel untuk menampung perulangan harga rumah dalam bentuk list
harga_rumah = []
for baris in data_harga_rumah[1:]:
	baris_harga_rumah = baris.replace("\n","").split(",")
	dict_harga_rumah = dict()
	for i in range(len(baris_harga_rumah)):
		dict_harga_rumah[key_harga_rumah[i]] = baris_harga_rumah[i]
	harga_rumah.append(dict_harga_rumah)
print(harga_rumah)
# Out:
# [{'tanah': '70', ' bangunan': ' 50', ' jarak_ke_pusat': ' 15', ' harga': ' 500'}, {'tanah': '70', ' bangunan': ' 60', ' jarak_ke_pusat': ' 30', ' harga': ' 400'}, {'tanah': '70', ' bangunan': ' 60', ' jarak_ke_pusat': ' 55', ' harga': ' 300'}, {'tanah': '100', ' bangunan': ' 50', ' jarak_ke_pusat': ' 30', ' harga': ' 700'}, {'tanah': '100', ' bangunan': ' 70', ' jarak_ke_pusat': ' 25', ' harga': ' 1000'}, {'tanah': '100', ' bangunan': ' 70', ' jarak_ke_pusat': ' 50', ' harga': ' 650'}, {'tanah': '120', ' bangunan': ' 100', ' jarak_ke_pusat': ' 20', ' harga': ' 2000'}, {'tanah': '120', ' bangunan': ' 80', ' jarak_ke_pusat': ' 50', ' harga': ' 1200'}, {'tanah': '150', ' bangunan': ' 100', ' jarak_ke_pusat': ' 50', ' harga': ' 1800'}, {'tanah': '150', ' bangunan': ' 90', ' jarak_ke_pusat': ' 15', ' harga': ' 3000'}]

# %% [markdown]
# Langkah 2
# * Buat fungsi  get_all_specified_attribute yang menerima parameter list_of_dictionary(tipe data list yang berisikan sekumpulan tipe data dictionary) dan specified_key (tipe data string).
# * Fungsi akan mengembalikan sebuah list yang berisikan seluruh atribut dengan kunci (key) specified_key.

# %%
# Buat fungsi  get_all_specified_attribute yang menerima parameter list_of_dictionary dan specified_key  
def get_all_specified_attributes(list_of_dictionary, specified_key):
	list_attributes = []
	for data in list_of_dictionary:
		attribute = data[specified_key]
		list_attributes.append(attribute)
  # mengembalikan sebuah list yang berisikan seluruh atribut dengan kunci specified_key.
	return list_attributes

# %% [markdown]
# Langkah 3

# %%
# Buat fungsi fungsi min_value yang menerima parameter list_attributes (berupa 
# tipe data list) dan mengembalikan nilai terkecil dalam list_attributes 
def min_value(list_attributes):
	min_attribute = 9999
	for attr in list_attributes:
		if int(attr) < min_attribute:
			min_attribute = int(attr)
	return min_attribute
# Buat fungsi dan max_value yang menerima parameter list_attribute dan 
# mengembalikan nilai terbesar dalam list_attributes.	
def max_value(list_attributes):
	max_attribute = -9999
	for attr in list_attributes:
		if int(attr) > max_attribute:
			max_attribute = int(attr)
	return max_attribute

# %% [markdown]
# Langkah 4

# %%
# Buat fungsi transform_attribute yang menerima parameter attr (sebuah 
# bilangan), max_attr (sebuah bilangan) dan min_attr (sebuah bilangan) 
# yang mengembalikan nilai transformasi dari sebuah attribute.
def transform_attribute(attr, max_attr, min_attr):
	nilai_transformasi = (attr - min_attr) / (max_attr - min_attr)
	return nilai_transformasi

# %% [markdown]
# Langkah 5

# %%
# Buat fungsi data_transformation yang menerima parameter list_of_dictionary 
# (sebuah list yang berisikan tipe data dictionary) dan list_attribute_names 
# (sebuah list yang berisikan tipe data string) mengembalikan hasil 
# transformasi data dari list_of_dictionary berdasarkan list_attribute_names 
# dan attr_info telah dispesifikasikan.
def data_transformation(list_of_dictionary, list_attribute_names):
	attr_info = {}
	for attr_name in list_attribute_names:
		specified_attributes = get_all_specified_attributes(list_of_dictionary, attr_name)
		max_attr = max_value(specified_attributes)
		min_attr = min_value(specified_attributes)
		attr_info[attr_name] = {'max': max_attr, 'min': min_attr}
		data_idx = 0
		while(data_idx < len(list_of_dictionary)):
			list_of_dictionary[data_idx][attr_name] = transform_attribute(int(list_of_dictionary[data_idx][attr_name]), max_attr, min_attr)
			data_idx += 1
	return list_of_dictionary, attr_info

# %% [markdown]
# Langkah 6

# %%
# Berdasarkan data baru dan attr_info ini, buat fungsi transform_data yang
# menerima parameter data dan attr_info dan mengembalikan nilai atribut 
# dari data baru yang telah ditransformasikan.
def transform_data(data, attr_info):
	for key_name in data.keys():
		data[key_name] = (data[key_name] - attr_info[key_name]['min']) / (attr_info[key_name]['max'] - attr_info[key_name]['min'])
	return data

# %% [markdown]
# Langkah 7

# %%
# Buat fungsi yang digunakan untuk sistem prediksi harga berdasarkan 
# nilai kemiripan atribut, yaitu argument input data dan list_of_data!
def abs_value(value):
	if value < 0:
		return -value
	else:
		return value
def price_based_on_similarity(data, list_of_data):
	prediksi_harga = 0
	perbedaan_terkecil = 999
	for data_point in list_of_data:
		  perbedaan= abs_value(data['tanah'] - data_point['tanah'])
		  perbedaan+= abs_value(data['bangunan'] - data_point['bangunan'])
		  perbedaan+= abs_value(data['jarak_ke_pusat'] - data_point['jarak_ke_pusat'])
		  if perbedaan < perbedaan_terkecil:
			    prediksi_harga = data_point['harga']
			    perbedaan_terkecil = perbedaan
	return prediksi_harga

# %% [markdown]
# Langkah 8

# %%
# Hitung harga rumah yang telah ditransformasikan ke dalam variabel 
# harga_rumah berikut dengan atributnya attr_info
harga_rumah, attr_info = data_transformation(harga_rumah, ['tanah','bangunan','jarak_ke_pusat'])
# Gunakan variabel data untuk memprediksi harga rumah
data = {'tanah': 110, 'bangunan': 80, 'jarak_ke_pusat': 35}
# Transformasikan data tersebut dengan dengan menggunakan attr_info yang telah 
# diperoleh yang kembali disimpan ke variabel data.
data = transform_data(data, attr_info)
# Hitunglah prediksi harga dari variabel data tersebut.
harga = price_based_on_similarity(data, harga_rumah)
print("Prediksi harga rumah: ", harga)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-9f6901fc495d> in <module>()
#       1 # Hitung harga rumah yang telah ditransformasikan ke dalam variabel
#       2 # harga_rumah berikut dengan atributnya attr_info
# ----> 3 harga_rumah, attr_info = data_transformation(harga_rumah, ['tanah','bangunan','jarak_ke_pusat'])
#       4 # Gunakan variabel data untuk memprediksi harga rumah
#       5 data = {'tanah': 110, 'bangunan': 80, 'jarak_ke_pusat': 35}
#
# <ipython-input-34-33c79aab4e48> in data_transformation(list_of_dictionary, list_attribute_names)
#       7         attr_info = {}
#       8         for attr_name in list_attribute_names:
# ----> 9                 specified_attributes = get_all_specified_attributes(list_of_dictionary, attr_name)
#      10                 max_attr = max_value(specified_attributes)
# ...

# %% [markdown]
# # Python Object Oriented Programming (OOP)
# struktur dari program dikemas ke objek yang terdiri dari
# *   properti (properties)
# *   fungsi (behaviours)
#
# konsep OOP mencegah program secara berulang kali (Don't Repeat Yourself)
#
# Konsep Utama
# *   Encapsulation, menyembunyikan sebagian detail yang dimiliki oleh sebuah objek pada objek lain
# *   Inheritance, menurunkan fungsi yang dimiliki oleh objek pada objek baru tanpa mengubah makna dari objeknya.
# *   Polymorphism, menggunakan fungsi dengan nama yang sama namun caranya berbeda

# %% [markdown]
# ### Class dan Object
# Pada Class terdapat 2 jenis atribut
# *   Class Attribute, atribut yang nilainya sama untuk oleh seluruh objek
# *   Instance Attribute, atribut yang nilainya beda-beda untuk setiap objek

# %%
# Definisikan class Karyawan
class Karyawan():
    nama_perusahaan = 'ABC'

# Inisiasi object yang dinyatakan dalam variabel aksara dan senja
aksara = Karyawan()
senja = Karyawan()

# Cetak nama perusahaan melalui penggunaan keyword __class__ pada class attribute nama_perusahaan
print(aksara.__class__.nama_perusahaan)

# Ubah nama_perusahaan menjadi 'DEF'
aksara.__class__.nama_perusahaan = 'DEF'
# Cetak nama_perusahaan objek aksara dan senja
print(aksara.__class__.nama_perusahaan)
print(senja.__class__.nama_perusahaan)
# Out:
# ABC
# DEF
# DEF

# %% [markdown]
# Penerapan Instance Attribute
#
# agar bisa memasukan argument pada class

# %%
# Definisikan class Karyawan
class Karyawan:
    nama_perusahaan = 'ABC'
    # inheritance atribut
    def __init__(self, nama, usia, pendapatan):
        self.nama = nama
        self.usia = usia
        self.pendapatan = pendapatan

# Buat object bernama aksara dan senja
aksara = Karyawan('Aksara', 25, 8500000)
senja = Karyawan('Senja', 28, 12500000)

# Cetak objek bernama aksara
print(aksara.nama + ', Usia: ' + str(aksara.usia) + ', Pendapatan ' + str(aksara.pendapatan))
# Cetak objek bernama senja
print(senja.nama + ', Usia: ' + str(senja.usia) + ', Pendapatan ' + str(senja.pendapatan))
# Out:
# Aksara, Usia: 25, Pendapatan 8500000
# Senja, Usia: 28, Pendapatan 12500000

# %% [markdown]
# Contoh soal

# %%
class Karyawan:
    nama_perusahaan = 'ABC'
    tunjangan_transportasi = 500000
    def __init__(self, nama, usia, pendapatan):
        self.nama = nama
        self.usia = usia
        self.pendapatan = pendapatan

# masukan argumen pada kelas
karyawan_1 = Karyawan('Budi', 35, 5000000)
karyawan_2 = Karyawan('Didi', 30, 5000000)
# panggil atribut dari kelas
karyawan_1.__class__.nama_perusahaan = 1000000

total_pengeluaran = karyawan_1.__class__.tunjangan_transportasi
total_pengeluaran += karyawan_2. __class__.tunjangan_transportasi
total_pengeluaran += karyawan_1.pendapatan
total_pengeluaran += karyawan_2.pendapatan
print(total_pengeluaran)
# Out:
# 11000000

# %% [markdown]
# Behavior pada Class

# %%
# Definisikan class Karyawan berikut dengan attribut dan fungsinya
class Karyawan:
    nama_perusahaan = 'ABC'
    insentif_lembur = 250000
    def __init__(self, nama, usia, pendapatan):
        self.nama = nama
        self.usia = usia
        self.pendapatan = pendapatan
        self.pendapatan_tambahan = 0
    def lembur(self):
        self.pendapatan_tambahan += self.insentif_lembur
    def tambahan_proyek(self, insentif_proyek):
    	self.pendapatan_tambahan += insentif_proyek
    def total_pendapatan(self):
    	return self.pendapatan + self.pendapatan_tambahan

# Buat object dari karwayan bernama Aksara dan Senja
aksara = Karyawan('Aksara', 25, 8500000)
senja = Karyawan('Senja', 28, 12500000)
# Aksara melaksanakan lembur
aksara.lembur()
# Senja memiliki proyek tambahan
senja.tambahan_proyek(2500000)

# Cetak pendapatan total Aksara dan Senja
print('Pendapatan Total Aksara: ' + str(aksara.total_pendapatan()))
print('Pendapatan Total Senja: ' +str(senja.total_pendapatan()))
# Out:
# Pendapatan Total Aksara: 8750000
# Pendapatan Total Senja: 15000000

# %% [markdown]
# Tugas Praktek
#
# buat sistem manajemen perusahaan sederhana dengan kelas Karyawan dan Perusahaan
#
# self sama seperti this di Java, C#, C++

# %%
# Definisikan class Karyawan
class Karyawan:
    def __init__(self, nama, usia, pendapatan, insentif_lembur): 
        self.nama = nama
        self.usia = usia
        self.pendapatan = pendapatan
        self.pendapatan_tambahan = 0
        self.insentif_lembur = insentif_lembur
    def lembur(self):
        self.pendapatan_tambahan += self.insentif_lembur
    def tambahan_proyek(self, jumlah_tambahan):
        self.pendapatan_tambahan += jumlah_tambahan
    def total_pendapatan(self):
        return self.pendapatan + self.pendapatan_tambahan
        
# Definisikan class Perusahaan
class Perusahaan:
    def __init__(self, nama, alamat, nomor_telepon): 
        self.nama = nama
        self.alamat = alamat
        self.nomor_telepon = nomor_telepon
        self.list_karyawan = []
    def aktifkan_karyawan(self, karyawan): 
        self.list_karyawan.append(karyawan)
    def nonaktifkan_karyawan(self, nama_karyawan): 
        karyawan_nonaktif = None
        for karyawan in self.list_karyawan:
            if karyawan.nama == nama_karyawan: 
                karyawan_nonaktif = karyawan
                break
        if karyawan_nonaktif is not None: 
            self.list_karyawan.remove(karyawan_nonaktif)

# %% [markdown]
# memasukan data - data dari perusahaan dan karyawan - karyawannya dengan menjalankan function dari program diatas

# %%
# Definisikan perusahaan
perusahaan = Perusahaan('ABC', 'Jl. Jendral Sudirman, Blok 11', '(021) 95205XX')

# Definisikan nama-nama karyawan
karyawan_1 = Karyawan('Ani', 25, 8500000, 100000)
karyawan_2 = Karyawan('Budi', 28, 12000000, 150000)
karyawan_3 = Karyawan('Cici', 30, 15000000, 200000)

# Aktifkan karyawan di perusahaan ABC
perusahaan.aktifkan_karyawan(karyawan_1) 
perusahaan.aktifkan_karyawan(karyawan_2) 
perusahaan.aktifkan_karyawan(karyawan_3)

# %% [markdown]
# ### Encapsulation & Inheritance
# Enkapsulasi, teknik dalam OOP yang mengizinkan untuk menyembunyikan detil dari atribut dalam class
#
# sehingga variabel tidak bisa diakses dari luar
#
# access modifier, untuk menentukan batas akses pada atribut dari class
# *   Public access, didefinisikan dengan secara langsung menuliskan atribut/ fungsinya
# *   Private access, didefinisikan dengan menambahkan double underscore (__) sebelum menuliskan atribut/ fungsinya

# %%
# Definisikan class Karyawan
class Karyawan: 
    nama_perusahaan = 'ABC' 
    # variabel private
    __insentif_lembur = 250000
    def __init__(self, nama, usia, pendapatan): 
        self.__nama = nama
        self.__usia = usia 
        self.__pendapatan = pendapatan 
        self.__pendapatan_tambahan = 0
    def lembur(self):
        self.__pendapatan_tambahan += self.__insentif_lembur 
    def tambahan_proyek(self, insentif_proyek):
        self.__pendapatan_tambahan +=insentif_proyek 
    def total_pendapatan(self):
        return self.__pendapatan + self.__pendapatan_tambahan
# Buat objek karyawan bernama Aksara
aksara = Karyawan('Aksara', 25, 8500000)
# Akses ke attribute class Karyawan
print(aksara.__class__.__nama_perusahaan)
# Akan menimbulkan error ketika di run
print(aksara.__nama)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-e22bffdd01fe> in <module>()
#      18 aksara = Karyawan('Aksara', 25, 8500000)
#      19 # Akses ke attribute class Karyawan
# ---> 20 print(aksara.__class__.__nama_perusahaan)
#      21 # Akan menimbulkan error ketika di run
#      22 print(aksara.__nama)
#
# AttributeError: type object 'Karyawan' has no attribute '__nama_perusahaan'

# %% [markdown]
# Inheritance,  untuk mendefinisikan class baru berdasarkan class sebelumnya
#
# *  class baru dapat memiliki atribut dan fungsi pada class yang sebelumnya didefinisikan
# *  atribut/fungsi yang diwariskan hanyalah atribut/fungsi dengan access modifier public, sedangkan yang make access modifier private tidak diturunkan

# %%
# Definisikan class Karyawan (sebagai base class)
class Karyawan: 
    nama_perusahaan = 'ABC' 
    insentif_lembur = 250000
    def __init__(self, nama, usia, pendapatan): 
        self.nama = nama
        self.usia = usia 
        self.pendapatan = pendapatan 
        self.pendapatan_tambahan = 0
    def lembur(self):
        self.pendapatan_tambahan += self.insentif_lembur 
    def tambahan_proyek(self, insentif_proyek):
        self.pendapatan_tambahan += insentif_proyek 
    def total_pendapatan(self):
        return self.pendapatan + self.pendapatan_tambahan

# class turunan sebagai child class

# Buat class turunan (sebagai inherit class) dari class karyawan, yaitu class AnalisData
class AnalisData(Karyawan):
    def __init__(self, nama, usia, pendapatan):
    # melakukan pemanggilan konstruktur class Karyawan 
        super().__init__(nama, usia, pendapatan)

# Buat kembali class turunan (sebagai inherit class) dari class karyawan, yaitu class IlmuwanData
class IlmuwanData(Karyawan):
    def __init__(self, nama, usia, pendapatan):
        # melakukan pemanggilan konstruktur class Karyawan 
        super().__init__(nama, usia, pendapatan)

# Buat objek karyawan yang bekerja sebagai AnalisData
aksara = AnalisData('Aksara', 25, 8500000)
aksara.lembur()
print(aksara.total_pendapatan())

# Buat objek karyawan yang bekerja sebagai IlmuwanData
senja = IlmuwanData('Senja', 28, 13000000)
senja.tambahan_proyek(2000000)
print(senja.total_pendapatan())
# Out:
# 8750000
# 15000000

# %% [markdown]
# fungsi super() merupakan child class yang mewarisi fungsi/atribut dari parent class dengan menggunakan
#
#
#
# ```
# # penerapan childclass
# class <ChildClass>(<ParentClass>):
#     def __init__(<deretan fungsi dari parent class>)
#         super().__init__((<deretan argumen dari parent class>)
# ```

# %%
# Definisikan class Karyawan (sebagai base class)
class Karyawan: 
    nama_perusahaan = 'ABC' 
    insentif_lembur = 250000
    def __init__(self, nama, usia, pendapatan): 
        self.nama = nama
        self.usia = usia 
        self.pendapatan = pendapatan 
        self.pendapatan_tambahan = 0
    def lembur(self):
        self.pendapatan_tambahan += self.insentif_lembur 
    def tambahan_proyek(self, insentif_proyek):
        self.pendapatan_tambahan += insentif_proyek 
    def total_pendapatan(self):
        return self.pendapatan + self.pendapatan_tambahan

# Buat class turunan (sebagai inherit class) dari class karyawan, yaitu class AnalisData
class AnalisData(Karyawan):
    def __init__(self, nama, usia, pendapatan):
    # melakukan pemanggilan konstruktur class Karyawan 
        super().__init__(nama, usia, pendapatan)

# Buat kembali class turunan (sebagai inherit class) dari class karyawan, yaitu class IlmuwanData
class IlmuwanData(Karyawan):
    # mengubah atribut insentif_lembur yang digunakan pada fungsi lembur()
    insentif_lembur = 500000
    def __init__(self, nama, usia, pendapatan): 
        super().__init__(nama, usia, pendapatan)

# Buat objek karyawan yang bekerja sebagai AnalisData
aksara = AnalisData('Aksara', 25, 8500000)
aksara.lembur()
print(aksara.total_pendapatan())

# Buat objek karyawan yang bekerja sebagai IlmuwanData
senja = IlmuwanData('Senja', 28, 13000000)
senja.lembur()
print(senja.total_pendapatan())
# Out:
# 8750000
# 13500000

# %% [markdown]
# ### Polymorphism
# untuk mendefinisikan kembali fungsi yang telah diwarisi oleh parent class
#
# dengan fungsi super. init()

# %%
# Definisikan class Karyawan (sebagai base class)
class Karyawan: 
    nama_perusahaan = 'ABC' 
    insentif_lembur = 250000
    def __init__(self, nama, usia, pendapatan): 
        self.nama = nama
        self.usia = usia 
        self.pendapatan = pendapatan 
        self.pendapatan_tambahan = 0
    def lembur(self):
        self.pendapatan_tambahan += self.insentif_lembur 
    def tambahan_proyek(self, insentif_proyek):
        self.pendapatan_tambahan += insentif_proyek 
    def total_pendapatan(self):
        return self.pendapatan + self.pendapatan_tambahan

# Buat class turunan (sebagai inherit class) dari class karyawan, yaitu class AnalisData
class AnalisData(Karyawan):
    def __init__(self, nama, usia, pendapatan):
    # melakukan pemanggilan konstruktur class Karyawan 
        super().__init__(nama, usia, pendapatan)
    # menerapkan polymorphism dengan mendefinisikan kembali fungsi 
    # lembur() pada class AnalisData 
    def lembur(self):
        # pendapatan tambahan pada class AnalisData sebesar 10 % dari pendapatannya.
        self.pendapatan_tambahan += int(self.pendapatan * 0.1)

# Buat objek karyawan yang bekerja sebagai AnalisData
aksara = AnalisData('Aksara', 25, 8500000)
aksara.lembur()
print(aksara.total_pendapatan())
# Out:
# 9350000

# %% [markdown]
# pada Inheritance, selain fungsi super() dapat mengakses constructor milik parent class, child class juga dapat mengakses atribut/fungsinya parent class.

# %%
# Definisikan class Karyawan (sebagai base class)
class Karyawan: 
    nama_perusahaan = 'ABC' 
    insentif_lembur = 250000
    def __init__(self, nama, usia, pendapatan): 
        self.nama = nama
        self.usia = usia 
        self.pendapatan = pendapatan 
        self.pendapatan_tambahan = 0
    def lembur(self):
        self.pendapatan_tambahan += self.insentif_lembur 
    def tambahan_proyek(self, insentif_proyek):
        self.pendapatan_tambahan += insentif_proyek 
    def total_pendapatan(self):
        return self.pendapatan + self.pendapatan_tambahan
# Buat class turunan (sebagai inherit class) dari class karyawan,yaitu class AnalisData
class AnalisData(Karyawan):
    def __init__(self, nama, usia, pendapatan): 
        super().__init__ (nama, usia, pendapatan)
    # mendefinisikan kembali fungsi lembur() pada class AnalisData 
    def lembur(self):
        # memanggil fungsi lembur pada class Karyawan 
        # super().<fungsi yang dipanggil>()
        super().lembur()
        # pendapatan tambahan pada class AnalisData sebesar
        # 5 % dari pendapatannya.
        self.pendapatan_tambahan += int(self.pendapatan * 0.05)
# Buat objek karyawan yang bekerja sebagai AnalisData
aksara = AnalisData('Aksara', 25, 8500000)
aksara.lembur()
print(aksara.total_pendapatan())

# %% [markdown]
# penghitungan pembayaran fee karyawan lepas
# *   dimulai dengan membuat class Tenaga lepas, berisi nama, usia, dan pendapatan selama bergabung di sebuah proyek
# *    karyawan lepas dapat insentif dari proyek yang dikerjakan. Kalau hasilnya sukses bisa dapat 1% dari nilai proyek

# %%
# Definisikan class Karyawan
class Karyawan:
    def __init__(self, nama, usia, pendapatan, insentif_lembur): 
        self.nama = nama
        self.usia = usia 
        self.pendapatan = pendapatan 
        self.pendapatan_tambahan = 0
        self.insentif_lembur = insentif_lembur 
    def lembur(self):
        self.pendapatan_tambahan += self.insentif_lembur 
    def tambahan_proyek(self,jumlah_tambahan):
        self.pendapatan_tambahan += jumlah_tambahan 
    def total_pendapatan(self):
        return self.pendapatan + self.pendapatan_tambahan

# Definisikan class TenagaLepas sebagai child class dari class Karyawan
class TenagaLepas(Karyawan):
    def __init__(self, nama, usia, pendapatan):
        super().__init__(nama, usia, pendapatan, 0)
    def tambahan_proyek(self, nilai_proyek):
        self.pendapatan_tambahan += nilai_proyek * 0.01

# %% [markdown]
# nambahin class yang merepresentasikan masing-masing pekerjaan di tiap divisi
#
# penerimaan fee berdasarkan divisi
# *   analisis data, dapet insentif tambahan sebesar 10%
# *   ilmuwan data, dapet insentif tambahan sebesar 10%
# *   pembersih data, dapet insentif tambahan sebesar 10%
# *   dokumenter teknis, satu - satunya divisi yang tidak menerima insentif dari proyek

# %%
# Definisikan class Karyawan sebagai parent class
class Karyawan:
    def __init__(self, nama, usia, pendapatan, insentif_lembur): 
        self.nama = nama
        self.usia = usia 
        self.pendapatan = pendapatan 
        self.pendapatan_tambahan = 0
        self.insentif_lembur = insentif_lembur 
    def lembur(self):
        self.pendapatan_tambahan += self.insentif_lembur 
    def tambahan_proyek(self,jumlah_tambahan):
        self.pendapatan_tambahan += jumlah_tambahan 
    def total_pendapatan(self):
        return self.pendapatan + self.pendapatan_tambahan
# Definisikan class TenagaLepas sebagai child class dari
# class Karyawan
class TenagaLepas(Karyawan):
    def __init__(self, nama, usia, pendapatan):
        super().__init__(nama, usia, pendapatan, 0)
    def tambahan_proyek(self, nilai_proyek):
        self.pendapatan_tambahan += nilai_proyek * 0.01
# Definisikan class AnalisData sebagai child class dari
# class Karyawan
class AnalisData(Karyawan): 
     pass
# Definisikan class IlmuwanData sebagai child class dari
# class Karyawan
class IlmuwanData(Karyawan):
    def tambahan_proyek(self, nilai_proyek): 
        self.pendapatan_tambahan += 0.1 * nilai_proyek
# Definisikan class PembersihData sebagai child class dari
# class TenagaLepas
class PembersihData(TenagaLepas): 
     pass
# Definisikan class DokumenterTeknis sebagai child class dari
# class TenagaLepas
class DokumenterTeknis(TenagaLepas):
    def tambahan_proyek(self, jumlah_tambahan): 
        return

# %% [markdown]
# Overloading,  class bisa punya fungsi yang namanya sama namun parameternya beda
# *   karena pada python tidak dapat mendeklarasikan fungsi (baik pada class ataupun tidak) dengan nama yang sama
# *   maka dapat menggunakan function default parameters

# %%
class Karyawan: 
    nama_perusahaan = 'ABC' 
    insentif_lembur = 250000
    # usia akan di-set nilainya menjadi 21 saat tidak
    # dispesifikasikan dan pendapatan akan di-set nilainya
    # menjadi 5000000 saat tidak dispesifikasikan
    def __init__(self, nama, usia=21, pendapatan=5000000): 
        self.nama = nama
        self.usia = usia
        self.pendapatan = pendapatan
        self.pendapatan_tambahan = 0
    def lembur(self):
        self.pendapatan_tambahan += self.insentif_lembur 
    def tambahan_proyek(self, insentif_proyek):
        self.pendapatan_tambahan += insentif_proyek 
    def total_pendapatan(self):
        return self.pendapatan + self.pendapatan_tambahan

# Karyawan baru pertama yang bernama Budi
karyawan_baru1 = Karyawan('Budi')
print(karyawan_baru1.nama)
print(karyawan_baru1.usia)
print(karyawan_baru1.total_pendapatan())

# Karyawan baru ke-2 yang bernama Didi, umur 25
karyawan_baru2 = Karyawan('Didi', 25)
print(karyawan_baru2.nama)
print(karyawan_baru2.usia)
print(karyawan_baru2.total_pendapatan())

# Karyawan baru ke-3 yang bernama Hadi, pendapatan 8000000
karyawan_baru3 = Karyawan('Hadi', pendapatan=8000000)
print(karyawan_baru3.nama)
print(karyawan_baru3.usia)
print(karyawan_baru3.total_pendapatan())
# Out:
# Budi
# 21
# 5000000
# Didi
# 25
# 5000000
# Hadi
# 21
# 8000000

# %% [markdown]
# ## Studi Kasus OOP
# ketentuan data
# *   analis data umumnya berusia 21, memiliki pendapatan senilai 6.500.000 dan insentif lembur senilai 100.000
# *   ilmuwan data umumnya berusia 25, memiliki pendapatan senilai 12.000.000, dan insentif lembur senilai 150.000
# *   tenaga lepas
#     *   pendapatan umum senilai 4000000 untuk pembersih data
#     *   pendapatan umum senilai 2500000 untuk dokumenter teknis
#
# mencetak total pengeluaran perusahaan dengan teknik polymorphism

# %%
# Definisikan class Karyawan sebagai parent class
class Karyawan:
    def __init__(self, nama, usia, pendapatan, insentif_lembur):
        self.nama = nama
        self.usia = usia 
        self.pendapatan = pendapatan 
        self.pendapatan_tambahan = 0
        self.insentif_lembur = insentif_lembur 
    def lembur(self):
        self.pendapatan_tambahan += self.insentif_lembur
    def tambahan_proyek(self,jumlah_tambahan):
        self.pendapatan_tambahan += jumlah_tambahan
    def total_pendapatan(self):
        return self.pendapatan + self.pendapatan_tambahan

# Definisikan class TenagaLepas sebagai child class dari class Karyawan 
class TenagaLepas(Karyawan):
    def __init__(self, nama, usia, pendapatan): 
        super().__init__(nama, usia, pendapatan, 0)
    def tambahan_proyek(self, nilai_proyek): 
        self.pendapatan_tambahan += nilai_proyek * 0.01

# Definisikan class AnalisData sebagai child class dari class Karyawan 
class AnalisData(Karyawan):
    def __init__(self, nama, usia = 21, pendapatan =  6500000, 
                 insentif_lembur = 100000):
        super().__init__(nama, usia, pendapatan, insentif_lembur) 

# Definisikan class IlmuwanData sebagai child class dari class Karyawan
class IlmuwanData(Karyawan):
    def __init__(self, nama, usia = 25, pendapatan = 12000000, 
                 insentif_lembur = 150000):
        super().__init__(nama, usia, pendapatan, insentif_lembur) 
    def tambahan_proyek(self, nilai_proyek):
        self.pendapatan_tambahan += 0.1 * nilai_proyek

# Definisikan class PembersihData sebagai child class dari class TenagaLepas
class PembersihData(TenagaLepas):
    def __init__(self, nama, usia, pendapatan = 4000000): 
        super().__init__(nama, usia, pendapatan)

# Definisikan class DokumenterTeknis sebagai child class dari class TenagaLepas
class DokumenterTeknis(TenagaLepas):
    def __init__(self, nama, usia, pendapatan =  2500000): 
        super().__init__(nama, usia, pendapatan)
        def tambahan_proyek(self, jumlah_tambahan): 
            return

# Definisikan class Perusahaan 
class Perusahaan :
    def __init__(self, nama, alamat, nomor_telepon): 
        self.nama = nama
        self.alamat = alamat 
        self.nomor_telepon = nomor_telepon 
        self.list_karyawan = []
    def aktifkan_karyawan(self, karyawan): 
        self.list_karyawan.append(karyawan)
    def nonaktifkan_karyawan(self, nama_karyawan): 
        karyawan_nonaktif = None
        for karyawan in self.list_karyawan:
            if karyawan.nama == nama_karyawan: 
                karyawan_nonaktif = karyawan 
                break
        if karyawan_nonaktif is not None: 
            self.list_karyawan.remove(karyawan_nonaktif)
    def total_pengeluaran(self): 
        pengeluaran = 0
        for karyawan in self.list_karyawan:
            pengeluaran += karyawan.total_pendapatan() 
        return pengeluaran
    def cari_karyawan(self, nama_karyawan): 
        for karyawan in self.list_karyawan:
            if karyawan.nama == nama_karyawan: 
                return karyawan
        return None
    # def daftar_karyawan(self, karyawan):
    #     for karyawan in self.list_karyawan:
    #         print(f'nama karyawan : {karyawan.nama}')

# Create object karyawan sesuai dengan tugasnya masing-masing
# seperti yang dinyatakan dalam tabel.
anin = PembersihData('Anindhita Rahma Cahyadi', 25)
beby = DokumenterTeknis('Beby Chaesara Anandila', 18)
cindy = IlmuwanData('Cindy Hapsari Maharani')
dey = IlmuwanData('Dhea Angelina', 32, 20000000)
eve = AnalisData('Eve Antoinette Ichwan')
febi = AnalisData('Febi Komaril', 28, 12000000)

# Create object perusahaan
perusahaan = Perusahaan('FX Sudirman', 'Jl. Jendral Sudirman, Blok 11', '(021) 95812XX')

# Aktifkan setiap karyawan yang telah didefinisikan
perusahaan.aktifkan_karyawan(anin)
perusahaan.aktifkan_karyawan(beby)
perusahaan.aktifkan_karyawan(cindy)
perusahaan.aktifkan_karyawan(dey)
perusahaan.aktifkan_karyawan(eve)
perusahaan.aktifkan_karyawan(febi)

# Cetak keseluruhan total pengeluaran perusahaan
# print(perusahaan.daftar_karyawan())
print(perusahaan.total_pengeluaran())
# Out:
# 57000000
